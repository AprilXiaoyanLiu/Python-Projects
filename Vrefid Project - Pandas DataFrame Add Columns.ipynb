# %%
import os
print os.getcwd()
# Out:
# /Users/April

# %%
import graphlab

# %%
sales = graphlab.SFrame('home_data.gl/')
# Out:
# [INFO] GraphLab Create v1.8.2 started. Logging: /tmp/graphlab_server_1455782029.log
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-3-e6a249ea422b> in <module>()
# ----> 1 sales = graphlab.SFrame('home_data.gl/')
#
# /Users/April/anaconda/envs/dato-env/lib/python2.7/site-packages/graphlab/data_structures/sframe.pyc in __init__(self, data, format, _proxy)
#     935                     pass
#     936                 else:
# --> 937                     raise ValueError('Unknown input type: ' + format)
#     938
#     939         sframe_size = -1
#
# /Users/April/anaconda/envs/dato-env/lib/python2.7/site-packages/graphlab/cython/context.pyc in __exit__(self, exc_type, exc_value, traceback)
#      47             if not self.show_cython_trace:
#      48                 # To hide cython trace, we re-raise from here
# ---> 49                 raise exc_type(exc_value)
#      50             else:
#      51                 # To show the full trace, we do nothing and let exception propagate
#
# IOError: Cannot open /Users/April/home_data.gl for read. Cannot open /Users/April/home_data.gl for reading: unspecified iostream_category error: unspecified iostream_category error: unspecified iostream_category error

# %%
import pandas

# %%
import numpy as np
import matplotlib as p
import pdb
from pandas import *

# %%
data = read_csv('campaign performance test.csv')
data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-dec792e7c1f0> in <module>()
# ----> 1 data = read_csv('campaign performance test.csv')
#       2 data
#
# /Users/April/anaconda/envs/dato-env/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, na_fvalues, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, float_precision, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols, infer_datetime_format, skip_blank_lines)
#     472                     skip_blank_lines=skip_blank_lines)
#     473
# --> 474         return _read(filepath_or_buffer, kwds)
#     475
#     476     parser_f.__name__ = name
#
# /Users/April/anaconda/envs/dato-env/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     248
#     249     # Create the parser.
# --> 250     parser = TextFileReader(filepath_or_buffer, **kwds)
#     251
#     252     if (nrows is not None) and (chunksize is not None):
#
# /Users/April/anaconda/envs/dato-env/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     564             self.options['has_index_names'] = kwds['has_index_names']
#     565
# --> 566         self._make_engine(self.engine)
#     567
#     568     def _get_options_with_defaults(self, engine):
#
# /Users/April/anaconda/envs/dato-env/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     703     def _make_engine(self, engine='c'):
#     704         if engine == 'c':
# --> 705             self._engine = CParserWrapper(self.f, **self.options)
#     706         else:
#     707             if engine == 'python':
#
# /Users/April/anaconda/envs/dato-env/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1070         kwds['allow_leading_cols'] = self.index_col is not False
#    1071
# -> 1072         self._reader = _parser.TextReader(src, **kwds)
#    1073
#    1074         # XXX
#
# pandas/parser.pyx in pandas.parser.TextReader.__cinit__ (pandas/parser.c:4814)()
#
# ValueError: No columns to parse from file

# %%
import numpy as np
import matplotlib as p
import pdb
from pandas import *
data = read_csv('test.csv')
data
# Out:
#   campaign adgroup data
# 0        1    dasc  das
# 1        3    dasc    d
# 2        4      da    d
# 3        d     ads    c

# %%
import pandas as pa
from pandas import Data.Frame
data = read_csv('test.csv')
data
# Out:
#   File "<ipython-input-1-97bd0cbd04db>", line 2
#     from pandas import Data.Frame
#                            ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import matplotlib as p
import pdb
from pandas import *
data = read_csv('test_vrefid.csv')
data
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-2-259df6ab5d77> in <module>()
#       3 import pdb
#       4 from pandas import *
# ----> 5 data = read_csv('test_vrefid.csv')
#       6 data
#
# /Users/April/anaconda/envs/dato-env/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, na_fvalues, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, float_precision, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols, infer_datetime_format, skip_blank_lines)
#     472                     skip_blank_lines=skip_blank_lines)
#     473
# --> 474         return _read(filepath_or_buffer, kwds)
#     475
#     476     parser_f.__name__ = name
#
# /Users/April/anaconda/envs/dato-env/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     248
#     249     # Create the parser.
# --> 250     parser = TextFileReader(filepath_or_buffer, **kwds)
#     251
#     252     if (nrows is not None) and (chunksize is not None):
#
# /Users/April/anaconda/envs/dato-env/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     564             self.options['has_index_names'] = kwds['has_index_names']
#     565
# --> 566         self._make_engine(self.engine)
#     567
#     568     def _get_options_with_defaults(self, engine):
#
# /Users/April/anaconda/envs/dato-env/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     703     def _make_engine(self, engine='c'):
#     704         if engine == 'c':
# --> 705             self._engine = CParserWrapper(self.f, **self.options)
#     706         else:
#     707             if engine == 'python':
#
# /Users/April/anaconda/envs/dato-env/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1070         kwds['allow_leading_cols'] = self.index_col is not False
#    1071
# -> 1072         self._reader = _parser.TextReader(src, **kwds)
#    1073
#    1074         # XXX
#
# pandas/parser.pyx in pandas.parser.TextReader.__cinit__ (pandas/parser.c:3173)()
#
# pandas/parser.pyx in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:5912)()
#
# IOError: File test_vrefid.csv does not exist

# %%
import numpy as np
import matplotlib as p
import pdb
from pandas import *
data = read_csv('test_vrefid.csv')
data
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-3-259df6ab5d77> in <module>()
#       3 import pdb
#       4 from pandas import *
# ----> 5 data = read_csv('test_vrefid.csv')
#       6 data
#
# /Users/April/anaconda/envs/dato-env/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, na_fvalues, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, float_precision, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols, infer_datetime_format, skip_blank_lines)
#     472                     skip_blank_lines=skip_blank_lines)
#     473
# --> 474         return _read(filepath_or_buffer, kwds)
#     475
#     476     parser_f.__name__ = name
#
# /Users/April/anaconda/envs/dato-env/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     248
#     249     # Create the parser.
# --> 250     parser = TextFileReader(filepath_or_buffer, **kwds)
#     251
#     252     if (nrows is not None) and (chunksize is not None):
#
# /Users/April/anaconda/envs/dato-env/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     564             self.options['has_index_names'] = kwds['has_index_names']
#     565
# --> 566         self._make_engine(self.engine)
#     567
#     568     def _get_options_with_defaults(self, engine):
#
# /Users/April/anaconda/envs/dato-env/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     703     def _make_engine(self, engine='c'):
#     704         if engine == 'c':
# --> 705             self._engine = CParserWrapper(self.f, **self.options)
#     706         else:
#     707             if engine == 'python':
#
# /Users/April/anaconda/envs/dato-env/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1070         kwds['allow_leading_cols'] = self.index_col is not False
#    1071
# -> 1072         self._reader = _parser.TextReader(src, **kwds)
#    1073
#    1074         # XXX
#
# pandas/parser.pyx in pandas.parser.TextReader.__cinit__ (pandas/parser.c:3173)()
#
# pandas/parser.pyx in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:5912)()
#
# IOError: File test_vrefid.csv does not exist

# %%
import numpy as np
import matplotlib as p
import pdb
from pandas import *
data = read_csv('test.csv')
data
# Out:
#   campaign adgroup data
# 0        1    dasc  das
# 1        3    dasc    d
# 2        4      da    d
# 3        d     ads    c

# 21         B - Business - Courses - Specific - Online
# 22         B - Business - Courses - Specific - Online
# 23         B - Business - Courses - Specific - Online
# 24  B - Business - Accounting Certificates - Gradu...
# 25  B - Business - Accounting Certificates - Gradu...
# 26  B - Business - Accounting Certificates - Gradu...
# 27  B - Business - Accounting Certificates - Gradu...
# 28  B - Business - Accounting Certificates - Gradu...
# 29  B - Business - Accounting Certificates - Gradu...
# 30  B - Business - Accounting Certificates - Gradu...
# 31  B - Business - Accounting Certificates - Gradu...
# 32  B - Business - Accounting Certificates - Gradu...
# 33  B - Business - Accounting Certificates - Gradu...
# 34  B - Business - Accounting Certificates - Gradu...
#
#                                               keyword match type  \
# 0                  online enterprise security courses      BROAD
# 1                  online enterprise security courses      BROAD
# 2                    online business management class      BROAD
# 3                    online business management class      BROAD
# 4                        online human services course      BROAD
# 5                        online human services course      BROAD
# 6                online e-business management courses      BROAD
# 7                online e-business management courses      BROAD
# 8   online creating change within organizations co...      BROAD
# 9   online creating change within organizations co...      BROAD
# 10              online business communication courses      BROAD
# 11              online business communication courses      BROAD
# 12                  online employee development class      BROAD
# 13                  online employee development class      BROAD
# 14           online organizational leadership classes      BROAD
# 15           online organizational leadership classes      BROAD
# 16              online call center operations classes      BROAD
# 17              online call center operations classes      BROAD
# 18                online finance for business courses      BROAD
# 19                online finance for business courses      BROAD
# 20                    online business systems courses      BROAD
# 21                    online business systems courses      BROAD
# 22           online human capital development courses      BROAD
# 23           online human capital development courses      BROAD
# 24      online graduate accounting certificate school      BROAD
# 25      online graduate accounting certificate school      BROAD
# 26    online graduate accounting certification school      BROAD
# 27    online graduate accounting certification school      BROAD
# 28             online graduate accounting certificate      BROAD
# 29             online graduate accounting certificate      BROAD
# 30     online graduate accounting certificate program      BROAD
# 31     online graduate accounting certificate program      BROAD
# 32  online graduate certificate program in accounting      BROAD
# 33  online graduate certificate program in accounting      BROAD
# 34          online graduate certificate in accounting      BROAD
#
#         Unnamed: 6                                        orignal url  \
# 0   destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 1   destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 2   destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 3   destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 4   destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 5   destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 6   destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 7   destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 8   destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 9   destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 10  destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 11  destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 12  destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 13  destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 14  destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 28  http://www.phoenix.edu/vr/businessandmanagemen...
# 29  http://www.phoenix.edu/vr/businessandmanagemen...
# 30  http://www.phoenix.edu/vr/businessandmanagemen...
# 31  http://www.phoenix.edu/vr/businessandmanagemen...
# 32  http://www.phoenix.edu/vr/businessandmanagemen...
# 33  http://www.phoenix.edu/vr/businessandmanagemen...
# 34  http://www.phoenix.edu/vr/businessandmanagemen...

# %%
orignal_url = data['orignal url']
new_url = data['new url']
orignal_url
new_url
# Out:
# 0     http://www.phoenix.edu/vr/businessandmanagemen...
# 1     http://www.phoenix.edu/vr/businessandmanagemen...
# 2     http://www.phoenix.edu/vr/businessandmanagemen...
# 3     http://www.phoenix.edu/vr/businessandmanagemen...
# 4     http://www.phoenix.edu/vr/businessandmanagemen...
# 5     http://www.phoenix.edu/vr/businessandmanagemen...
# 6     http://www.phoenix.edu/vr/businessandmanagemen...
# 7     http://www.phoenix.edu/vr/businessandmanagemen...
# 8     http://www.phoenix.edu/vr/businessandmanagemen...
# 9     http://www.phoenix.edu/vr/businessandmanagemen...
# 10    http://www.phoenix.edu/vr/businessandmanagemen...
# 11    http://www.phoenix.edu/vr/businessandmanagemen...
# 12    http://www.phoenix.edu/vr/businessandmanagemen...
# 13    http://www.phoenix.edu/vr/businessandmanagemen...
# 14    http://www.phoenix.edu/vr/businessandmanagemen...
# 15    http://www.phoenix.edu/vr/businessandmanagemen...
# 16    http://www.phoenix.edu/vr/businessandmanagemen...
# 17    http://www.phoenix.edu/vr/businessandmanagemen...
# 18    http://www.phoenix.edu/vr/businessandmanagemen...
# 19    http://www.phoenix.edu/vr/businessandmanagemen...
# 20    http://www.phoenix.edu/vr/businessandmanagemen...
# 21    http://www.phoenix.edu/vr/businessandmanagemen...
# 22    http://www.phoenix.edu/vr/businessandmanagemen...
# 23    http://www.phoenix.edu/vr/businessandmanagemen...
# 24    http://www.phoenix.edu/vr/businessandmanagemen...
# 25    http://www.phoenix.edu/vr/businessandmanagemen...
# 26    http://www.phoenix.edu/vr/businessandmanagemen...
# 27    http://www.phoenix.edu/vr/businessandmanagemen...
# 28    http://www.phoenix.edu/vr/businessandmanagemen...
# 29    http://www.phoenix.edu/vr/businessandmanagemen...
# 30    http://www.phoenix.edu/vr/businessandmanagemen...
# 31    http://www.phoenix.edu/vr/businessandmanagemen...
# 32    http://www.phoenix.edu/vr/businessandmanagemen...
# 33    http://www.phoenix.edu/vr/businessandmanagemen...
# 34    http://www.phoenix.edu/vr/businessandmanagemen...
# Name: new url, dtype: object

# %%
original_vrefid = []
for row in orignal_url:
    position = row.find('&vrefid')
    o_vrefid = row[position+8:position+16]
    original_vrefid.append(o_vrefid)
print original_vrefid
# Out:
# ['BusSD328', 'BusSD328', 'BusSD318', 'BusSD318', 'BusSD334', 'BusSD334', 'BusSD327', 'BusSD327', 'BusSD325', 'BusSD325', 'BusSD317', 'BusSD317', 'BusSD327', 'BusSD327', 'BusSD353', 'BusSD353', 'BusSD321', 'BusSD321', 'BusSD330', 'BusSD330', 'BusSD320', 'BusSD320', 'BusSD333', 'BusSD333', 'BusSD331', 'BusSD331', 'BusSD331', 'BusSD331', 'BusSD331', 'BusSD331', 'BusSD331', 'BusSD331', 'BusSD332', 'BusSD332', 'BusSD332']

# 0   destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 1   destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 2   destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 3   destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 4   destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 5   destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 6   destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 7   destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 8   destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 9   destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 10  destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 11  destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 12  destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 13  destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 14  destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 15  destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 16  destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 17  destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 18  destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 19  destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 20  destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 21  destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 22  destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 23  destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 24  destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 25  destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 26  destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 27  destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 28  destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 29  destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 30  destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 31  destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 32  destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 33  destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
# 34  destinationUrl  http://www.phoenix.edu/vr/businessandmanagemen...
#
#                                               new url original_vrefid  \
# 0   http://www.phoenix.edu/vr/businessandmanagemen...        BusSD328
# 1   http://www.phoenix.edu/vr/businessandmanagemen...        BusSD328
# 2   http://www.phoenix.edu/vr/businessandmanagemen...        BusSD318
# 3   http://www.phoenix.edu/vr/businessandmanagemen...        BusSD318
# 4   http://www.phoenix.edu/vr/businessandmanagemen...        BusSD334
# 5   http://www.phoenix.edu/vr/businessandmanagemen...        BusSD334
# 6   http://www.phoenix.edu/vr/businessandmanagemen...        BusSD327
# 7   http://www.phoenix.edu/vr/businessandmanagemen...        BusSD327
# 8   http://www.phoenix.edu/vr/businessandmanagemen...        BusSD325
# 9   http://www.phoenix.edu/vr/businessandmanagemen...        BusSD325
# 10  http://www.phoenix.edu/vr/businessandmanagemen...        BusSD317
# 11  http://www.phoenix.edu/vr/businessandmanagemen...        BusSD317
# 12  http://www.phoenix.edu/vr/businessandmanagemen...        BusSD327
# 13  http://www.phoenix.edu/vr/businessandmanagemen...        BusSD327
# 14  http://www.phoenix.edu/vr/businessandmanagemen...        BusSD353
# 15  http://www.phoenix.edu/vr/businessandmanagemen...        BusSD353
# 16  http://www.phoenix.edu/vr/businessandmanagemen...        BusSD321
# 17  http://www.phoenix.edu/vr/businessandmanagemen...        BusSD321
# 18  http://www.phoenix.edu/vr/businessandmanagemen...        BusSD330
# 19  http://www.phoenix.edu/vr/businessandmanagemen...        BusSD330
# 20  http://www.phoenix.edu/vr/businessandmanagemen...        BusSD320
# 21  http://www.phoenix.edu/vr/businessandmanagemen...        BusSD320
# 22  http://www.phoenix.edu/vr/businessandmanagemen...        BusSD333
# 23  http://www.phoenix.edu/vr/businessandmanagemen...        BusSD333
# 24  http://www.phoenix.edu/vr/businessandmanagemen...        BusSD331
# 25  http://www.phoenix.edu/vr/businessandmanagemen...        BusSD331
# 26  http://www.phoenix.edu/vr/businessandmanagemen...        BusSD331
# 27  http://www.phoenix.edu/vr/businessandmanagemen...        BusSD331
# 28  http://www.phoenix.edu/vr/businessandmanagemen...        BusSD331
# 29  http://www.phoenix.edu/vr/businessandmanagemen...        BusSD331
# 30  http://www.phoenix.edu/vr/businessandmanagemen...        BusSD331
# 31  http://www.phoenix.edu/vr/businessandmanagemen...        BusSD331
# 32  http://www.phoenix.edu/vr/businessandmanagemen...        BusSD332
# 33  http://www.phoenix.edu/vr/businessandmanagemen...        BusSD332
# 34  http://www.phoenix.edu/vr/businessandmanagemen...        BusSD332
#
#    new_vrefid
# 0    wFWLoOba
# 1    wFWLoOba
# 2    l4RGXlhb
# 3    l4RGXlhb
# 4    fLBvze3k
# 5    fLBvze3k
# 6    sMhiNMgw
# 7    sMhiNMgw
# 8    VYJBL60k
# 9    VYJBL60k
# 10   JitUZwm7
# 11   JitUZwm7
# 12   TjgKMgaL
# 13   TjgKMgaL
# 14   rxDNxed9
# 15   rxDNxed9
# 16   W1KmrB19
# 17   W1KmrB19
# 18   hVqzYqec
# 19   hVqzYqec
# 20   kCyoGruG
# 21   kCyoGruG
# 22   turuCPeh
# 23   turuCPeh
# 24   klarC6fp
# 25   klarC6fp
# 26   mwfV9rNW
# 27   mwfV9rNW
# 28   N5yCxiDP
# 29   N5yCxiDP
# 30   OVFPF154
# 31   OVFPF154
# 32   4fqAUQh9
# 33   4fqAUQh9
# 34   OcWNaN4x

# %%
data.to_csv('update_vrefid_test.csv', index=False)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-90f14cd73cd8> in <module>()
# ----> 1 pd.Dataframe.to_csv('update_vrefid_test.csv',data)
#
# AttributeError: 'module' object has no attribute 'Dataframe'

# %%
data.to_csv('update_vrefid_test.csv')
